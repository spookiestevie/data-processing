# %%
import csv #process csv
import wget#download data
import pandas as pd #import into datafram
import time #converting string d/m/y to unix time
import datetime
import matplotlib.pyplot as plt
import numpy as np
import sklearn.linear_model


#download data file
print('Beginning file download with wget module')

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'  
wget.download(url, '/home/anand/auto-mpg.data')
# Out:
# Beginning file download with wget module
# u'/home/anand/auto-mpg (1).data'

# %%
#open data file
with open('/home/anand/auto-mpg.data') as csvfile:
    for row in csvfile:
        print(row)
# Out:
# 18.0   8   307.0      130.0      3504.      12.0   70  1	"chevrolet chevelle malibu"
#
# 15.0   8   350.0      165.0      3693.      11.5   70  1	"buick skylark 320"
#
# 18.0   8   318.0      150.0      3436.      11.0   70  1	"plymouth satellite"
#
# 16.0   8   304.0      150.0      3433.      12.0   70  1	"amc rebel sst"
#
# 17.0   8   302.0      140.0      3449.      10.5   70  1	"ford torino"
#
# 15.0   8   429.0      198.0      4341.      10.0   70  1	"ford galaxie 500"
#
# 14.0   8   454.0      220.0      4354.       9.0   70  1	"chevrolet impala"
#
# 14.0   8   440.0      215.0      4312.       8.5   70  1	"plymouth fury iii"
#
# 14.0   8   455.0      225.0      4425.      10.0   70  1	"pontiac catalina"
#
# 15.0   8   390.0      190.0      3850.       8.5   70  1	"amc ambassador dpl"
#
# 15.0   8   383.0      170.0      3563.      10.0   70  1	"dodge challenger se"
#
# 14.0   8   340.0      160.0      3609.       8.0   70  1	"plymouth 'cuda 340"
#
# ...

# %%
data = pd.read_csv('/home/anand/auto-mpg.data', header=None, sep='\s{2,}', engine='python')#split cols where whitespace>2

# %%
#what to plot
#headers none
#separate
'''1. mpg: continuous
2. cylinders: multi-valued discrete
3. displacement: continuous
4. horsepower: continuous
5. weight: continuous
6. acceleration: continuous
7. model year: multi-valued discrete
8. origin: multi-valued discrete
9. car name: string (unique for each instance'''

col_names = ['mpg','cylinders','disp','hp','weight','accel','year','name']
data.columns=col_names

# %%
data.head()
# Out:
#     mpg  cylinders   disp     hp  weight  accel  year  \
# 0  18.0          8  307.0  130.0  3504.0   12.0    70
# 1  15.0          8  350.0  165.0  3693.0   11.5    70
# 2  18.0          8  318.0  150.0  3436.0   11.0    70
# 3  16.0          8  304.0  150.0  3433.0   12.0    70
# 4  17.0          8  302.0  140.0  3449.0   10.5    70
#
#                              name
# 0  1\t"chevrolet chevelle malibu"
# 1          1\t"buick skylark 320"
# 2         1\t"plymouth satellite"
# 3              1\t"amc rebel sst"
# 4                1\t"ford torino"

# %%
data.plot(x='disp', y='mpg', style='o')
